# %%
import pandas as pd

# %%
zomato=pd.read_csv("C:/Users/Asus/Documents/data analyst/Excel files/Zomato_Dataset.csv")

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
zomato.tail()
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 45579                   26.912328                    75.804257  24-03-2022
# ...

# %% [markdown]
# # columns helps to get all the  names of columns of the datasheet.

# %%
zomato.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %% [markdown]
# # all important columns descriptions is given below:

# %% [markdown]
# *'ID': unique identifier for each delivery.*
# * 'Delivery_person_ID':unique indentity of delivery agent.*
# * 'Delivery_person_Age':age of the delivery agent.*
# * 'Delivery_person_Ratings: aggregate ratings given to him by different customers.*
# *  'Order_Date':date of the order.*
# *  'Time_Orderd':time of the order was placed.*
# *  'Time_Order_picked':the time at which the order was picked for delivery.*
# *  'Weather_conditions':weather at the time of delivery.*
# * 'Road_traffic_density':how many vehicles were therein the road  at the time of delivery.*
# * 'Type_of_order': the order type like: snacks,drinks,buffet.*
# * 'Type_of_vehicle':the type of vehicle used for the delivery.*
# * 'multiple_deliveries':it tells that how many deliveries the agent made in the same trip.*
# * 'Festival':it tells whether it was the time of any festival or not at the time of the delivery.*
# * 'Time_taken (min)': how much time the  agent took for the delivery.*

# %%
zomato.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# # isnull() helps to identify all the null values, and the sum() gives the total number of null values in each columns.

# %%
zomato.shape
# Out:
# (45584, 20)

# %% [markdown]
# .shape helps to know total rows and columns in the datasheet.

# %% [markdown]
# # down below we will fill all the null values with some appt values.

# %% [markdown]
# # Age

# %%
x=zomato['Delivery_person_Age'].median()
print(x)
# Out:
# 30.0

# %%
zomato['Delivery_person_Age']=zomato['Delivery_person_Age'].fillna(x)

# %% [markdown]
# .fill na will fill all the null values with 30 i.e median.

# %% [markdown]
# # RATING

# %%
x=zomato["Delivery_person_Ratings"].median()
print(x)
# Out:
# 4.7

# %%
zomato["Delivery_person_Ratings"]=zomato["Delivery_person_Ratings"].fillna(x)

# %% [markdown]
# # weather conditons`

# %%
x=zomato['Weather_conditions'].value_counts()
print(x)
# Out:
# Weather_conditions
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: count, dtype: int64

# %% [markdown]
# # .value_counts() tell us the count of number of occurence of each unique value in dataframe

# %%
zomato['Weather_conditions'] = zomato['Weather_conditions'].fillna('Sunny')
zomato['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Sunny         7898
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Name: count, dtype: int64

# %% [markdown]
# ### Road_traffic_density

# %%
zomato['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %%
zomato['Road_traffic_density'] = zomato['Road_traffic_density'].fillna('Low')

# %% [markdown]
# # multiple deliveries

# %%
zomato['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1.0    28151
# 0.0    14094
# 2.0     1985
# 3.0      361
# Name: count, dtype: int64

# %%
zomato[zomato['multiple_deliveries'] == 0.0] # Multiple deliveries can't be 0,atleast it should be 1
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 11     0x5795   RANCHIRES06DEL02                 31.0
# 16     0x3231      JAPRES16DEL03                 27.0
# 17     0x8bc0      SURRES15DEL03                 35.0
# 19     0x3c5e     PUNERES04DEL01                 23.0
# ...       ...                ...                  ...
# 45565  0x90c5      MUMRES20DEL03                 21.0
# 45573  0x59ae     PUNERES13DEL02                 30.0
# 45575  0xa333     CHENRES08DEL02                 37.0
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 3                          4.3            30.899584             75.809346
# 11                         4.7            23.357804             85.325146
# 16                         5.0            26.849596             75.800512
# ...

# %%
zomato['multiple_deliveries']=zomato['multiple_deliveries'].replace({0.0:1.0})

# %%
zomato['multiple_deliveries'] = zomato['multiple_deliveries'].fillna(1)

# %% [markdown]
# # festival

# %%
zomato['Festival'].value_counts()
# Out:
# Festival
# No     44460
# Yes      896
# Name: count, dtype: int64

# %%
y = zomato['Festival'].mode()[0]
zomato['Festival'] = zomato['Festival'].fillna(y)

# %% [markdown]
# # city

# %%
zomato['City'].value_counts()
# Out:
# City
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
a= zomato['City'].mode()[0]
zomato['City']=zomato['City'].fillna(a)

# %%
zomato['City'].value_counts()
# Out:
# City
# Metropolitian    35287
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
zomato.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# # here we can observe that all the null values have been successfully replaced by the apt value.

# %% [markdown]
# # time ordered

# %%
'09:20'.split(':')
# Out:
# ['09', '20']

# %%
def time_window(time_ordered):
    try:
        hour = int(time_ordered.split(':')[0])
    except:
        return 'Not defined'
        
    
    if hour>= 7 and hour<=12:
        return 'morning'
    elif hour>= 4 and hour< 7:
        return 'early morning'
    elif hour>12 and hour<=17:
        return 'afternoon'
    elif hour >17 and hour<= 22:
        return 'evening'
    elif hour> 22 and hour<=24:
        return 'late evening'
    elif hour>= 0 and hour<4:
        return 'late evening'

# %%
time_window('8:00')
# Out:
# 'morning'

# %%
zomato['Time_Orderd'] = zomato['Time_Orderd'].apply(time_window)

# %% [markdown]
# # it is used to apply the given function to each row.

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
# !pip install geopy

# %%
from geopy.distance import geodesic

# %%
zomato.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %% [markdown]
# # down below is function to calculate Distance.

# %%
def distance(each_row):
    restaurant_loc = (each_row['Restaurant_latitude'], each_row['Restaurant_longitude'])
    delivery_loc = (each_row['Delivery_location_latitude'], each_row['Delivery_location_longitude'])
    return geodesic(restaurant_loc, delivery_loc).kilometers

# %% [markdown]
# # now apply the function to create a new row called 'Distance'.

# %%
zomato['Distance']=zomato.apply(distance,axis=1)

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %% [markdown]
# # the above used .apply function helps to apply a function on each element in series and each row or column in dataframe.

# %%
zomato.drop(['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude', 'Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Order_picked'], 
            axis = 1, inplace = True)

# %% [markdown]
# * now dropping the columns that are not useful or required

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# ...

# %% [markdown]
# # Descriptive analysis¶

# %% [markdown]
# # :- it gives the basic summary about the dataset.

# %%
zomato.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition  \
# count         45584.000000             45584.000000       45584.000000
# mean             29.584525                 4.636546           1.023385
# std               5.696221                 0.327931           0.839055
# min              15.000000                 1.000000           0.000000
# 25%              25.000000                 4.600000           0.000000
# 50%              30.000000                 4.700000           1.000000
# 75%              34.000000                 4.800000           2.000000
# max              50.000000                 6.000000           3.000000
#
#        multiple_deliveries  Time_taken (min)      Distance
# count         45584.000000      45584.000000  45584.000000
# mean              1.059385         26.293963     99.216342
# std               0.267766          9.384298   1100.033036
# min               1.000000         10.000000      1.463837
# ...

# %% [markdown]
# ** from the above analysis we observed that the difference between the mean(99.21) and median(9.24) is huge ,it is because of the outlier in data in max i.e=19709.

# %%
zomato[zomato['Distance']<100]
# Out:
#        Delivery_person_Age  Delivery_person_Ratings   Time_Orderd  \
# 0                     36.0                      4.2       evening
# 1                     21.0                      4.7     afternoon
# 2                     23.0                      4.7     afternoon
# 3                     34.0                      4.3       morning
# 4                     24.0                      4.7       evening
# ...                    ...                      ...           ...
# 45579                 30.0                      4.8       morning
# 45580                 21.0                      4.6       evening
# 45581                 30.0                      4.9  late evening
# 45582                 20.0                      4.7     afternoon
# 45583                 23.0                      4.9     afternoon
#
#       Weather_conditions Road_traffic_density  Vehicle_condition  \
# 0                    Fog                  Jam                  2
# ...

# %%
zomato['Distance'] = zomato['Distance'].where(zomato['Distance'] <= 1000, zomato['Distance'].median())

# %%
zomato.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition  \
# count         45584.000000             45584.000000       45584.000000
# mean             29.584525                 4.636546           1.023385
# std               5.696221                 0.327931           0.839055
# min              15.000000                 1.000000           0.000000
# 25%              25.000000                 4.600000           0.000000
# 50%              30.000000                 4.700000           1.000000
# 75%              34.000000                 4.800000           2.000000
# max              50.000000                 6.000000           3.000000
#
#        multiple_deliveries  Time_taken (min)      Distance
# count         45584.000000      45584.000000  45584.000000
# mean              1.059385         26.293963      9.714177
# std               0.267766          9.384298      5.572293
# min               1.000000         10.000000      1.463837
# ...

# %% [markdown]
# # charts analysis

# %% [markdown]
# # 1: univariate analysis
#    **countplot:**
#     <br> **displot**
#     <br> **boxplot**
#     <br> **kdeplot**
#     <br> **piechart**

# %% [markdown]
# # 2: BIVARIATE ANALYSIS

# %% [markdown]
# **scatter:**
# <br> **boxplot**
# <br> **heatmap**
# <br> **stripplot**

# %% [markdown]
# # 3: multivariate analysis

# %% [markdown]
# **Hue**
# <br> **lmplot**
# <br> **subplot**
# <br> **facetgrid**

# %%
zomato.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Time_Orderd',
#        'Weather_conditions', 'Road_traffic_density', 'Vehicle_condition',
#        'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival',
#        'City', 'Time_taken (min)', 'Distance'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # countplot

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'Time_Orderd',data= zomato)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * from the above  we can observe that there are maximum people of age 30 as compared to any other age.

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'Type_of_order',data= zomato)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * from the above chart we can observe that all the types of food are mostly equally ordered .

# %% [markdown]
# # displot

# %%
sns.displot(zomato['Time_taken (min)'],kde=True)
plt.show()

# %% [markdown]
# * the above chart shows that the maximum time taken for delivery lies between somewhere around 25-30 min.

# %%
sns.displot(zomato['Time_taken (min)'],kde=True,bins=[5,10,15,20,25,30])
plt.show()

# %% [markdown]
# * here we have set bin range according to our requirement.

# %% [markdown]
# # kde plot

# %%
sns.kdeplot(zomato['Delivery_person_Age'])
plt.show()

# %% [markdown]
# * it shows only kde(kernel density estimation) line. Kde helps to visualize the density of a continuous variable.

# %% [markdown]
# # box plot

# %%
sns.boxplot(zomato['Delivery_person_Age'])
plt.show()

# %% [markdown]
#  * the boxplot shows a visual representation of dataset,it also helps to identify outliers.<br>
#  * the line inside the rectangular box shows us the median(middle value).<br>
#  * the rectangular lower and upper edges represent 25th and 75th percentile.

# %% [markdown]
# # observation from the above

# %% [markdown]
# * the median age is 30.<br>
# * the 25% lies on 25 age.<br>
# *  the 75% lies on somewhere around 34 age.
# *  the max age is somehere around 37 or 38 and beyond that is considered as outliers.

# %%
plt.pie(zomato['Type_of_order'].value_counts(),labels=zomato['Type_of_order'].value_counts().index)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# * legend() helps us to define legends  in pie chart.

# %% [markdown]
# # bivariate analysis

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# ...

# %%
zomato.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Time_Orderd',
#        'Weather_conditions', 'Road_traffic_density', 'Vehicle_condition',
#        'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival',
#        'City', 'Time_taken (min)', 'Distance'],
#       dtype='object')

# %%
sns.scatterplot(x='Distance',y='Time_taken (min)',data= zomato,color='lime')
plt.show()

# %%
sns.boxplot(x='Road_traffic_density',y='Time_taken (min)',data=zomato,color='red')
plt.show()

# %% [markdown]
# **observation**: the highest median is of jam and the minimum median if of low as compared to others.

# %%
sns.stripplot(x='Type_of_order',y='Time_taken (min)',data=zomato,color='gold')
# Out:
# <Axes: xlabel='Type_of_order', ylabel='Time_taken (min)'>

# %%
sns.heatmap(zomato.corr(numeric_only = True) ,annot=True)
plt.show()

# %% [markdown]
# **Observations**
# <br> There is negative correlation between Time taken and ratings ```(-0.34)```
# <br> There is negative correlation between Time taken and vehicle condition  ```(-0.24)```
# <br> There is positive correlation between Time taken and multiple deliveries ```(0.38)```
# <br> There is positive correlation between Time taken and distance ```(0.32)```
# <br> There is negative correlation between Time taken and ratings ```(-0.34)```

# %% [markdown]
# # multivariate analysis.

# %%
zomato.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Time_Orderd',
#        'Weather_conditions', 'Road_traffic_density', 'Vehicle_condition',
#        'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival',
#        'City', 'Time_taken (min)', 'Distance'],
#       dtype='object')

# %%
plt.figure(figsize= (8,8))
sns.scatterplot(x = 'Time_taken (min)', y = 'Delivery_person_Ratings', hue = 'Weather_conditions' ,data = zomato)
plt.show()

# %% [markdown]
# **observation** : we can observe that between the time 35-45 min,there is decrease in ratings,although the weather is sunny.

# %%
plt.figure(figsize= (8,5))
sns.lmplot(x= 'Distance', y = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density',data = zomato)
plt.show()

# %%
plt.figure(figsize= (8,8))
sns.lmplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density', col= 'multiple_deliveries' , data = zomato)
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8)) 


sns.scatterplot(x= 'Delivery_person_Ratings', y= 'Time_taken (min)', data=zomato, ax=axes[0, 0])
sns.boxplot(x= 'Vehicle_condition', y= 'Time_taken (min)', data=zomato, ax=axes[0, 1])
sns.boxplot(x='Type_of_order', y='Time_taken (min)', data=zomato, ax=axes[1, 0])
sns.scatterplot(x = 'Distance', y = 'Time_taken (min)', data = zomato, ax=axes[1, 1])
sns.histplot(data=zomato['Delivery_person_Age'],ax=axes[2,0])
sns.barplot(x='Road_traffic_density',y='Time_taken (min)',data= zomato,ax=axes[2,1])



axes[0, 0].set_title('Delivery_person_Ratings')
axes[0, 1].set_title('Vehicle_condition')
axes[1, 0].set_title('Type_of_order')
axes[1, 1].set_title('Type_of_order')
axes[2, 0].set_title('Delivery_person_Age')
axes[2,1].set_title('barplot')
plt.tight_layout()
plt.show()

# %% [markdown]
# # observation :
#                     1.the time taken is affecting the ratings.
#                     2.traffic density is also affecting the time taken.
